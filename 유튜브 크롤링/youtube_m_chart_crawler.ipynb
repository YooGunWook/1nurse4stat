# %% [markdown]
# # 참고사이트 :
# [파이썬을 이용한 유튜브 채널 크롤링, csv파일로 만들기](https://jh-0323.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%84-%EC%9D%B4%EC%9A%A9%ED%95%9C-%EC%9C%A0%ED%8A%9C%EB%B8%8C-%EC%B1%84%EB%84%90-%ED%81%AC%EB%A1%A4%EB%A7%81-csv%ED%8C%8C%EC%9D%BC%EB%A1%9C-%EB%A7%8C%EB%93%A4%EA%B8%B0)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cd3d5d7c7d06> in <module>
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.common.keys import Keys
#       3 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'selenium'

# %%
### * 크롬 웹드라이버 설치 후, webdriver.Chrome() 내부에 경로 입력

# %%
driver = webdriver.Chrome('C:/chromedriver_win32/chromedriver.exe')
driver.get('https://charts.youtube.com/charts/TopVideos/kr?hl=ko')
page = driver.page_source

# %% [markdown]
# # 차트의 제목, 채널명 추출

# %%
soup = BeautifulSoup(page,'lxml')
all_title = soup.find_all('span','ytmc-ellipsis-text style-scope')
titles = [soup.find_all('span','ytmc-ellipsis-text style-scope')[n].string for n in range(0,len(all_title))]
titles
# Out:
# ["(여자)아이들((G)I-DLE) - 'Oh my god' Official Music Video",
#  ' ',
#  "(여자)아이들((G)I-DLE) - 'Oh my god' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  '[슬기로운 의사생활 OST Part 3] 조정석 (CHO JUNG SEOK) - 아로하 (Aloha) MV',
#  'Stone Music Entertainment',
#  'ITZY "WANNABE" M/V',
#  'jypentertainment',
#  '[MV] ZICO(지코) _ Any song(아무노래)',
#  '1theK (원더케이)',
#  "BTS (방탄소년단) 'ON' Kinetic Manifesto Film : Come Prima",
#  'Big Hit Labels',
#  "WINNER - '뜸(Hold)' M/V",
#  'WINNER',
#  "IZ*ONE (아이즈원) - 'FIESTA' MV",
#  'Stone Music Entertainment',
#  '[슬기로운 의사생활 OST Part 2] 조이 (JOY) (레드벨벳) - 좋은 사람 있으면 소개시켜줘 (Introduce me a good person) MV',
#  'Stone Music Entertainment',
#  '[홍진영] HONGJINYOUNG 사랑은 꽃잎처럼 (Love is like a petal) M/V',
#  'Stone Music Entertainment',
#  '[MV] IU(아이유) _ Blueming(블루밍)',
#  '1theK (원더케이)',
#  "BTS (방탄소년단) 'ON' Official MV",
#  'Big Hit Labels',
#  '[MV] M.C the MAX(엠씨 더 맥스) _ BLOOM(처음처럼)',
#  '1theK (원더케이)',
#  '영탁-니가 왜 거기서 나와',
#  'OGAM Entertainment',
#  '[슬기로운 의사생활 OST Part 4] 규현 (KYUHYUN) - 화려하지 않은 고백 (Confession Is Not Flashy) MV',
#  'Stone Music Entertainment',
#  "Red Velvet 레드벨벳 'Psycho' MV",
#  'SMTOWN',
#  '크리스토퍼 (Christopher) - BAD 가사 번역 라이브 비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '버스커 버스커 (Busker Busker) - 벚꽃 엔딩',
#  'Stone Music Entertainment',
#  "BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) (feat. Halsey)' Official MV",
#  'Big Hit Labels',
#  "윤딴딴 / Yun DDanDDan - '니가 보고싶은 밤' (The Night i miss you) LIVE / in 자취방",
#  '윤딴딴 / Yun Ddan Ddan',
#  'TWICE "Feel Special" M/V',
#  'jypentertainment',
#  "(여자)아이들((G)I-DLE) - 'LION' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  "BTS (방탄소년단) 'Black Swan' Official MV",
#  'Big Hit Labels',
#  '로이킴 (Roy Kim) - 봄봄봄 (BOM BOM BOM) MV',
#  'Stone Music Entertainment',
#  '비 RAIN - 깡 GANG Official M/V',
#  'GENIE MUSIC',
#  '앤-마리 (Anne-Marie) - BIRTHDAY [Live at The Church Studios] 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '숀 (SHAUN) - 웨이백홈 (Way Back Home) [Lyric Video]',
#  'SHAUN',
#  'NAUL(나얼) _ Memory Of The Wind(바람기억) MV',
#  '1theK (원더케이)',
#  '[MV] 마마무(MAMAMOO) - HIP',
#  'MAMAMOO',
#  '왁스 (Wax) - 화장을 고치고 (Putting On A Make-Up) Official MV',
#  'WEJHYS J 위지스제이',
#  'Idina Menzel, Evan Rachel Wood - Show Yourself (From "Frozen 2"/ Sing-Along)',
#  'DisneyMusicVEVO',
#  "WINNER - 'Remember' M/V",
#  'WINNER',
#  "NCT 127 엔시티 127 '영웅 (英雄; Kick It)' MV",
#  'SMTOWN',
#  "10cm / 십센치 - '봄이 좋냐?? (What The Spring??)' Official Music Video ENG sub.",
#  'MAGIC STRAWBERRY SOUND',
#  '마크툽,이라온,반광옥,정영은,전상근-오늘도 빛나는 너에게(To You My Light) End Game [8K]',
#  'Official MAKTUB',
#  "BLACKPINK - '뚜두뚜두 (DDU-DU DDU-DU)' 2019 Coachella Live Performance",
#  'BLACKPINK',
#  '[MV] CODE KUNST(코드 쿤스트) _ Flower(꽃) (Feat. Jay Park(박재범), Woo(우원재), GIRIBOY(기리보이))',
#  '1theK (원더케이)',
#  '[MV] CODE KUNST(코드 쿤스트) _ JOKE! (Feat. C JAMM, Simon Dominic(사이먼 도미닉))',
#  '1theK (원더케이)',
#  '강다니엘(KANGDANIEL) - 2U M/V',
#  'KONNECT Entertainment',
#  '박군-한잔해',
#  'OGAM Entertainment',
#  '[8K]마크툽,이라온,반광옥,정영은,전상근-마음이 말하는 행복 Happy Ending',
#  'Official MAKTUB',
#  '두아 리파 (Dua Lipa) - New Rules 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[MV] BOL4(볼빨간사춘기) _ Bom(나만, 봄)',
#  '1theK (원더케이)',
#  '앤-마리 (Anne-Marie) - BIRTHDAY 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  "IU(아이유) 'Blueming(블루밍)' 라이브🎤🎤(밴드ver.) | 가사 | 스페셜클립 | Special Clip | LYRICS [4K]",
#  '1theK Originals - 원더케이 오리지널',
#  'TONES AND I - DANCE MONKEY (OFFICIAL VIDEO)',
#  'Tones And I',
#  "MAX 최강창민 'Chocolate' MV",
#  'SMTOWN',
#  '나비보벳따우 3개 국어로 부르기 (feat. 일본어, 영어, 한국어)',
#  'Hale In Ocean 정혜일',
#  '[MV] Jeong Eun Ji(정은지) _ Hopefully sky(하늘바라기) (Feat. 하림)',
#  '1theK (원더케이)',
#  '장범준3집 당신과는천천히 뮤직비디오_ MV',
#  '장범준',
#  'Dua Lipa - Break My Heart (Official Video)',
#  'Dua Lipa',
#  'EVERGLOW (에버글로우) - DUN DUN MV',
#  'Stone Music Entertainment',
#  'TAEYEON - Into the Unknown (From "Frozen 2"/Official Video)',
#  'disneymusicasiaVEVO',
#  '두아 리파 (Dua Lipa) - Break My Heart 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '리쌍 (LeeSSang) - 광대 | Clowns (With B.M.K) Official MV',
#  'WEJHYS J 위지스제이',
#  '[MV] V (BTS) - Sweet Night [이태원 클라쓰 OST Part.12 (ITAEWON CLASS OST Part.12)]',
#  'VLENDING 블렌딩',
#  '[MV] BOL4(볼빨간사춘기) _ Workaholic(워커홀릭)',
#  '1theK (원더케이)',
#  "(여자)아이들((G)I-DLE) - 'Oh my god' Official Lyric Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  'Eminem - Godzilla ft. Juice WRLD (Dir. by @_ColeBennett_)',
#  'Lyrical Lemonade',
#  '[LIVE] 가호(Gaho) - 시작(Start) [이태원클라쓰 OST Part.2 (ITAEWON CLASS OST Part.2)]',
#  '가호 Gaho',
#  '[MV] Han Yo Han(한요한) _ 400km (Feat. Kid Milli)',
#  '1theK (원더케이)',
#  '[MV] Gain(가인) _ Fxxk U (Feat. Bumkey)',
#  '1theK (원더케이)',
#  "Dua Lipa - Don't Start Now (Official Music Video)",
#  'Dua Lipa',
#  '순수하게 누구가를 사랑할수있던 그때^^ 마법의 성입니다',
#  'mc sniper',
#  '[MV] Gain(가인) _ Carnival (The Last Day)',
#  '1theK (원더케이)',
#  "SONG MINHO - '겁' (feat. TAEYANG) 0821 Mnet SHOW ME THE MONEY 4",
#  'WINNER',
#  'Idina Menzel, AURORA - Into the Unknown (From "Frozen 2")',
#  'DisneyMusicVEVO',
#  'Future - Life Is Good (Official Music Video) ft. Drake',
#  'Future',
#  '[MV] Crush(크러쉬) _ Sometimes(가끔)',
#  '1theK (원더케이)',
#  '[MV] HIGH4, IU(하이포, 아이유) _ Not Spring, Love, or Cherry Blossoms(봄,사랑,벚꽃 말고)',
#  '1theK (원더케이)',
#  '블락비 (Block B) - YESTERDAY MV',
#  'Stone Music Entertainment',
#  "(여자)아이들((G)I-DLE) - '한(一)(HANN(Alone))' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  '두아 리파 (Dua Lipa) - IDGAF 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[사랑의 불시착 OST Part 4] 백예린 (Yerin Baek) - 다시 난, 여기 (Here I Am Again) MV',
#  'Stone Music Entertainment',
#  "BTS (방탄소년단) '불타오르네 (FIRE)' Official MV",
#  'Big Hit Labels',
#  'Lee Seung Gi(이승기) _ Return(되돌리다) MV',
#  '1theK (원더케이)',
#  '[MV] T-ARA(티아라), Choshinsung(초신성) _ TTL Listen 2',
#  '1theK (원더케이)',
#  "SUHO 수호 '사랑, 하자 (Let’s Love)' MV",
#  'SMTOWN',
#  '위대한 쇼맨 (The Greatest Showman) OST - Never Enough 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '2PM “My House(우리집)” M/V',
#  'jypentertainment',
#  '트러블 메이커_내일은 없어 (Now by Trouble Maker of Mcountdown 2013.11.07)',
#  'Mnet K-POP',
#  'Park Bogum & Irene - One and Half | 박보검 & 아이린 - 일과 이분의 일 [Music Bank HOT Stage / 2015.05.01]',
#  'KBS World',
#  'IU(아이유) _ YOU&I(너랑나) MV',
#  '1theK (원더케이)',
#  "Kim, Bumsoo '2016 그댄 행복에 살텐데' ♪ 슈가맨 16회",
#  'JTBC Entertainment',
#  'Dua Lipa - Physical (Official Video)',
#  'Dua Lipa',
#  "(여자)아이들((G)I-DLE) - 'Uh-Oh' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  "TAEYEON 태연 'I (feat. Verbal Jint)' MV",
#  'SMTOWN',
#  'Doja Cat - Say So (Official Video)',
#  'Doja Cat',
#  'Lil Mosey - Blueberry Faygo (Dir. by @_ColeBennett_)',
#  'Lyrical Lemonade',
#  'วิธีบอกเลิก - ก้อง ห้วยไร่ [ OFFICIAL MV ]',
#  'ก้อง ห้วยไร่',
#  'Red Velvet 레드벨벳 - Psycho @ReVe Festival FINALE',
#  'Red Velvet',
#  '[MV] OVAN(오반) _ I Need You(어떻게 지내)',
#  '1theK (원더케이)',
#  'SG워너비 (SG WANNABE) - 가시리 MV',
#  'Stone Music Entertainment',
#  "NCT 127 엔시티 127 '영웅 (英雄; Kick It)' Performance Video",
#  'NCT 127',
#  '[MV] IU(아이유) _ Twenty-three(스물셋)',
#  '1theK (원더케이)',
#  'YooA (OH MY GIRL) - Lights Up (Harry Styles) cover.',
#  'OH MY GIRL',
#  '윤종신 - 좋니 [세로 라이브]ㅣSERO LIVEㅣ딩고뮤직ㅣDingo Music',
#  '딩고 뮤직 / dingo music',
#  "슈프림팀(Supreme Team) - '그땐 그땐 그땐' M/V",
#  'Amoeba Culture (아메바컬쳐)',
#  '클린 밴딧 (Clean Bandit) - Symphony feat. Zara Larsson 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[MV] Epitone Project(에피톤 프로젝트) _ first love(첫사랑)',
#  '1theK (원더케이)',
#  '패닉! 앳 더 디스코 (Panic! At The Disco) - High Hopes 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)']

# %%
titles[0:2]=[]
titles
# Out:
# ["(여자)아이들((G)I-DLE) - 'Oh my god' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  '[슬기로운 의사생활 OST Part 3] 조정석 (CHO JUNG SEOK) - 아로하 (Aloha) MV',
#  'Stone Music Entertainment',
#  'ITZY "WANNABE" M/V',
#  'jypentertainment',
#  '[MV] ZICO(지코) _ Any song(아무노래)',
#  '1theK (원더케이)',
#  "BTS (방탄소년단) 'ON' Kinetic Manifesto Film : Come Prima",
#  'Big Hit Labels',
#  "WINNER - '뜸(Hold)' M/V",
#  'WINNER',
#  "IZ*ONE (아이즈원) - 'FIESTA' MV",
#  'Stone Music Entertainment',
#  '[슬기로운 의사생활 OST Part 2] 조이 (JOY) (레드벨벳) - 좋은 사람 있으면 소개시켜줘 (Introduce me a good person) MV',
#  'Stone Music Entertainment',
#  '[홍진영] HONGJINYOUNG 사랑은 꽃잎처럼 (Love is like a petal) M/V',
#  'Stone Music Entertainment',
#  '[MV] IU(아이유) _ Blueming(블루밍)',
#  '1theK (원더케이)',
#  "BTS (방탄소년단) 'ON' Official MV",
#  'Big Hit Labels',
#  '[MV] M.C the MAX(엠씨 더 맥스) _ BLOOM(처음처럼)',
#  '1theK (원더케이)',
#  '영탁-니가 왜 거기서 나와',
#  'OGAM Entertainment',
#  '[슬기로운 의사생활 OST Part 4] 규현 (KYUHYUN) - 화려하지 않은 고백 (Confession Is Not Flashy) MV',
#  'Stone Music Entertainment',
#  "Red Velvet 레드벨벳 'Psycho' MV",
#  'SMTOWN',
#  '크리스토퍼 (Christopher) - BAD 가사 번역 라이브 비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '버스커 버스커 (Busker Busker) - 벚꽃 엔딩',
#  'Stone Music Entertainment',
#  "BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) (feat. Halsey)' Official MV",
#  'Big Hit Labels',
#  "윤딴딴 / Yun DDanDDan - '니가 보고싶은 밤' (The Night i miss you) LIVE / in 자취방",
#  '윤딴딴 / Yun Ddan Ddan',
#  'TWICE "Feel Special" M/V',
#  'jypentertainment',
#  "(여자)아이들((G)I-DLE) - 'LION' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  "BTS (방탄소년단) 'Black Swan' Official MV",
#  'Big Hit Labels',
#  '로이킴 (Roy Kim) - 봄봄봄 (BOM BOM BOM) MV',
#  'Stone Music Entertainment',
#  '비 RAIN - 깡 GANG Official M/V',
#  'GENIE MUSIC',
#  '앤-마리 (Anne-Marie) - BIRTHDAY [Live at The Church Studios] 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '숀 (SHAUN) - 웨이백홈 (Way Back Home) [Lyric Video]',
#  'SHAUN',
#  'NAUL(나얼) _ Memory Of The Wind(바람기억) MV',
#  '1theK (원더케이)',
#  '[MV] 마마무(MAMAMOO) - HIP',
#  'MAMAMOO',
#  '왁스 (Wax) - 화장을 고치고 (Putting On A Make-Up) Official MV',
#  'WEJHYS J 위지스제이',
#  'Idina Menzel, Evan Rachel Wood - Show Yourself (From "Frozen 2"/ Sing-Along)',
#  'DisneyMusicVEVO',
#  "WINNER - 'Remember' M/V",
#  'WINNER',
#  "NCT 127 엔시티 127 '영웅 (英雄; Kick It)' MV",
#  'SMTOWN',
#  "10cm / 십센치 - '봄이 좋냐?? (What The Spring??)' Official Music Video ENG sub.",
#  'MAGIC STRAWBERRY SOUND',
#  '마크툽,이라온,반광옥,정영은,전상근-오늘도 빛나는 너에게(To You My Light) End Game [8K]',
#  'Official MAKTUB',
#  "BLACKPINK - '뚜두뚜두 (DDU-DU DDU-DU)' 2019 Coachella Live Performance",
#  'BLACKPINK',
#  '[MV] CODE KUNST(코드 쿤스트) _ Flower(꽃) (Feat. Jay Park(박재범), Woo(우원재), GIRIBOY(기리보이))',
#  '1theK (원더케이)',
#  '[MV] CODE KUNST(코드 쿤스트) _ JOKE! (Feat. C JAMM, Simon Dominic(사이먼 도미닉))',
#  '1theK (원더케이)',
#  '강다니엘(KANGDANIEL) - 2U M/V',
#  'KONNECT Entertainment',
#  '박군-한잔해',
#  'OGAM Entertainment',
#  '[8K]마크툽,이라온,반광옥,정영은,전상근-마음이 말하는 행복 Happy Ending',
#  'Official MAKTUB',
#  '두아 리파 (Dua Lipa) - New Rules 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[MV] BOL4(볼빨간사춘기) _ Bom(나만, 봄)',
#  '1theK (원더케이)',
#  '앤-마리 (Anne-Marie) - BIRTHDAY 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  "IU(아이유) 'Blueming(블루밍)' 라이브🎤🎤(밴드ver.) | 가사 | 스페셜클립 | Special Clip | LYRICS [4K]",
#  '1theK Originals - 원더케이 오리지널',
#  'TONES AND I - DANCE MONKEY (OFFICIAL VIDEO)',
#  'Tones And I',
#  "MAX 최강창민 'Chocolate' MV",
#  'SMTOWN',
#  '나비보벳따우 3개 국어로 부르기 (feat. 일본어, 영어, 한국어)',
#  'Hale In Ocean 정혜일',
#  '[MV] Jeong Eun Ji(정은지) _ Hopefully sky(하늘바라기) (Feat. 하림)',
#  '1theK (원더케이)',
#  '장범준3집 당신과는천천히 뮤직비디오_ MV',
#  '장범준',
#  'Dua Lipa - Break My Heart (Official Video)',
#  'Dua Lipa',
#  'EVERGLOW (에버글로우) - DUN DUN MV',
#  'Stone Music Entertainment',
#  'TAEYEON - Into the Unknown (From "Frozen 2"/Official Video)',
#  'disneymusicasiaVEVO',
#  '두아 리파 (Dua Lipa) - Break My Heart 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '리쌍 (LeeSSang) - 광대 | Clowns (With B.M.K) Official MV',
#  'WEJHYS J 위지스제이',
#  '[MV] V (BTS) - Sweet Night [이태원 클라쓰 OST Part.12 (ITAEWON CLASS OST Part.12)]',
#  'VLENDING 블렌딩',
#  '[MV] BOL4(볼빨간사춘기) _ Workaholic(워커홀릭)',
#  '1theK (원더케이)',
#  "(여자)아이들((G)I-DLE) - 'Oh my god' Official Lyric Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  'Eminem - Godzilla ft. Juice WRLD (Dir. by @_ColeBennett_)',
#  'Lyrical Lemonade',
#  '[LIVE] 가호(Gaho) - 시작(Start) [이태원클라쓰 OST Part.2 (ITAEWON CLASS OST Part.2)]',
#  '가호 Gaho',
#  '[MV] Han Yo Han(한요한) _ 400km (Feat. Kid Milli)',
#  '1theK (원더케이)',
#  '[MV] Gain(가인) _ Fxxk U (Feat. Bumkey)',
#  '1theK (원더케이)',
#  "Dua Lipa - Don't Start Now (Official Music Video)",
#  'Dua Lipa',
#  '순수하게 누구가를 사랑할수있던 그때^^ 마법의 성입니다',
#  'mc sniper',
#  '[MV] Gain(가인) _ Carnival (The Last Day)',
#  '1theK (원더케이)',
#  "SONG MINHO - '겁' (feat. TAEYANG) 0821 Mnet SHOW ME THE MONEY 4",
#  'WINNER',
#  'Idina Menzel, AURORA - Into the Unknown (From "Frozen 2")',
#  'DisneyMusicVEVO',
#  'Future - Life Is Good (Official Music Video) ft. Drake',
#  'Future',
#  '[MV] Crush(크러쉬) _ Sometimes(가끔)',
#  '1theK (원더케이)',
#  '[MV] HIGH4, IU(하이포, 아이유) _ Not Spring, Love, or Cherry Blossoms(봄,사랑,벚꽃 말고)',
#  '1theK (원더케이)',
#  '블락비 (Block B) - YESTERDAY MV',
#  'Stone Music Entertainment',
#  "(여자)아이들((G)I-DLE) - '한(一)(HANN(Alone))' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  '두아 리파 (Dua Lipa) - IDGAF 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[사랑의 불시착 OST Part 4] 백예린 (Yerin Baek) - 다시 난, 여기 (Here I Am Again) MV',
#  'Stone Music Entertainment',
#  "BTS (방탄소년단) '불타오르네 (FIRE)' Official MV",
#  'Big Hit Labels',
#  'Lee Seung Gi(이승기) _ Return(되돌리다) MV',
#  '1theK (원더케이)',
#  '[MV] T-ARA(티아라), Choshinsung(초신성) _ TTL Listen 2',
#  '1theK (원더케이)',
#  "SUHO 수호 '사랑, 하자 (Let’s Love)' MV",
#  'SMTOWN',
#  '위대한 쇼맨 (The Greatest Showman) OST - Never Enough 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '2PM “My House(우리집)” M/V',
#  'jypentertainment',
#  '트러블 메이커_내일은 없어 (Now by Trouble Maker of Mcountdown 2013.11.07)',
#  'Mnet K-POP',
#  'Park Bogum & Irene - One and Half | 박보검 & 아이린 - 일과 이분의 일 [Music Bank HOT Stage / 2015.05.01]',
#  'KBS World',
#  'IU(아이유) _ YOU&I(너랑나) MV',
#  '1theK (원더케이)',
#  "Kim, Bumsoo '2016 그댄 행복에 살텐데' ♪ 슈가맨 16회",
#  'JTBC Entertainment',
#  'Dua Lipa - Physical (Official Video)',
#  'Dua Lipa',
#  "(여자)아이들((G)I-DLE) - 'Uh-Oh' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  "TAEYEON 태연 'I (feat. Verbal Jint)' MV",
#  'SMTOWN',
#  'Doja Cat - Say So (Official Video)',
#  'Doja Cat',
#  'Lil Mosey - Blueberry Faygo (Dir. by @_ColeBennett_)',
#  'Lyrical Lemonade',
#  'วิธีบอกเลิก - ก้อง ห้วยไร่ [ OFFICIAL MV ]',
#  'ก้อง ห้วยไร่',
#  'Red Velvet 레드벨벳 - Psycho @ReVe Festival FINALE',
#  'Red Velvet',
#  '[MV] OVAN(오반) _ I Need You(어떻게 지내)',
#  '1theK (원더케이)',
#  'SG워너비 (SG WANNABE) - 가시리 MV',
#  'Stone Music Entertainment',
#  "NCT 127 엔시티 127 '영웅 (英雄; Kick It)' Performance Video",
#  'NCT 127',
#  '[MV] IU(아이유) _ Twenty-three(스물셋)',
#  '1theK (원더케이)',
#  'YooA (OH MY GIRL) - Lights Up (Harry Styles) cover.',
#  'OH MY GIRL',
#  '윤종신 - 좋니 [세로 라이브]ㅣSERO LIVEㅣ딩고뮤직ㅣDingo Music',
#  '딩고 뮤직 / dingo music',
#  "슈프림팀(Supreme Team) - '그땐 그땐 그땐' M/V",
#  'Amoeba Culture (아메바컬쳐)',
#  '클린 밴딧 (Clean Bandit) - Symphony feat. Zara Larsson 가사번역 by 영화번역가 황석희',
#  '워너뮤직코리아 (Warner Music Korea)',
#  '[MV] Epitone Project(에피톤 프로젝트) _ first love(첫사랑)',
#  '1theK (원더케이)',
#  '패닉! 앳 더 디스코 (Panic! At The Disco) - High Hopes 가사 번역 뮤직비디오',
#  '워너뮤직코리아 (Warner Music Korea)']

# %% [markdown]
# # 제목과 채널 리스트로 분리

# %%
channel = titles[1::2]
title = titles[::2]

# %% [markdown]
# # 등수, 조회수 등 기타 정보 추출

# %%
c = soup.find_all('span','style-scope ytmc-chart-table')
views =[soup.find_all('span','style-scope ytmc-chart-table')[n].string for n in range(0,len(c))]

# %%
n = 4
views_res = [views[i*n:(i+1)*n] for i in
            range((len(views)+n-1) // n)]
print(views_res)
# Out:
# [['--', '1 week', '--', '1.79M'], ['지난주 #2', '2 weeks', '-10.6%', '510K'], ['지난주 #3', '5 weeks', '-2.1%', '495K'], ['지난주 #4', '13 weeks', '-2.6%', '404K'], ['지난주 #6', '7 weeks', '-8.8%', '320K'], ['지난주 #1', '3 weeks', '-67.5%', '301K'], ['지난주 #9', '8 weeks', '11.2%', '290K'], ['지난주 #8', '3 weeks', '0.9%', '263K'], ['지난주 #84', '2 weeks', '342.4%', '262K'], ['지난주 #10', '21 weeks', '2.5%', '252K'], ['지난주 #7', '7 weeks', '-15.9%', '234K'], ['지난주 #5', '3 weeks', '-42.8%', '230K'], ['지난주 #15', '14 weeks', '15.5%', '220K'], ['--', '1 week', '--', '205K'], ['지난주 #12', '14 weeks', '-2.5%', '202K'], ['지난주 #16', '38 weeks', '7.8%', '201K'], ['지난주 #14', '26 weeks', '-3%', '196K'], ['지난주 #17', '52 weeks', '4.7%', '193K'], ['지난주 #24', '4 weeks', '14.8%', '175K'], ['지난주 #31', '29 weeks', '30.3%', '169K'], ['--', '21 weeks', '--', '152K'], ['지난주 #20', '6 weeks', '-9.4%', '148K'], ['지난주 #26', '31 weeks', '-2.9%', '142K'], ['지난주 #25', '21 weeks', '-6.6%', '141K'], ['지난주 #28', '5 weeks', '4.4%', '141K'], ['지난주 #30', '30 weeks', '6.8%', '140K'], ['지난주 #29', '20 weeks', '5.6%', '138K'], ['지난주 #33', '22 weeks', '6.6%', '135K'], ['지난주 #32', '16 weeks', '3.6%', '132K'], ['지난주 #19', '2 weeks', '-21.2%', '130K'], ['--', '1 week', '--', '128K'], ['지난주 #18', '5 weeks', '-27.3%', '128K'], ['지난주 #40', '9 weeks', '16.4%', '127K'], ['지난주 #22', '28 weeks', '-20.1%', '124K'], ['--', '1 week', '--', '122K'], ['--', '1 week', '--', '122K'], ['지난주 #66', '4 weeks', '51.8%', '118K'], ['지난주 #21', '3 weeks', '-26.3%', '117K'], ['지난주 #38', '28 weeks', '2%', '116K'], ['지난주 #39', '4 weeks', '1.4%', '112K'], ['지난주 #42', '20 weeks', '4.7%', '111K'], ['지난주 #50', '29 weeks', '18.1%', '110K'], ['지난주 #43', '9 weeks', '3.9%', '108K'], ['지난주 #58', '19 weeks', '30.9%', '107K'], ['지난주 #52', '20 weeks', '19.8%', '105K'], ['--', '1 week', '--', '103K'], ['지난주 #65', '2 weeks', '31.1%', '102K'], ['지난주 #51', '17 weeks', '12.1%', '102K'], ['지난주 #37', '12 weeks', '-16.2%', '101K'], ['지난주 #35', '2 weeks', '-23.2%', '95.5K'], ['지난주 #49', '10 weeks', '0.5%', '94.6K'], ['지난주 #45', '20 weeks', '-7.1%', '94.1K'], ['--', '1 week', '--', '93.6K'], ['지난주 #48', '7 weeks', '-2.3%', '92.9K'], ['지난주 #36', '4 weeks', '-24.9%', '92.2K'], ['지난주 #61', '23 weeks', '11.9%', '90.6K'], ['--', '1 week', '--', '88.4K'], ['지난주 #44', '5 weeks', '-15.2%', '86.9K'], ['지난주 #46', '8 weeks', '-11.8%', '84.7K'], ['지난주 #59', '2 weeks', '3.2%', '84K'], ['지난주 #41', '9 weeks', '-23.2%', '82.8K'], ['지난주 #64', '16 weeks', '5.3%', '82.8K'], ['--', '3 weeks', '--', '82.7K'], ['지난주 #27', '5 weeks', '-39.5%', '82.5K'], ['지난주 #82', '14 weeks', '33.3%', '81.6K'], ['지난주 #54', '19 weeks', '-3.5%', '81.4K'], ['지난주 #56', '12 weeks', '-3.7%', '80.6K'], ['지난주 #73', '7 weeks', '18.9%', '80.5K'], ['지난주 #86', '34 weeks', '37.9%', '79.7K'], ['지난주 #83', '24 weeks', '28.9%', '77.6K'], ['--', '22 weeks', '--', '77.2K'], ['지난주 #71', '6 weeks', '7.8%', '73.6K'], ['지난주 #63', '13 weeks', '-9.1%', '71.7K'], ['지난주 #74', '4 weeks', '5.7%', '70.4K'], ['지난주 #67', '4 weeks', '-5.6%', '69.9K'], ['지난주 #81', '2 weeks', '12.7%', '69.4K'], ['지난주 #11', '2 weeks', '-71.4%', '69.4K'], ['--', '25 weeks', '--', '68.7K'], ['--', '7 weeks', '--', '67.8K'], ['--', '4 weeks', '--', '66.9K'], ['지난주 #53', '3 weeks', '-23.9%', '66.3K'], ['지난주 #89', '8 weeks', '17.4%', '66.2K'], ['지난주 #78', '9 weeks', '3.8%', '65.5K'], ['지난주 #57', '4 weeks', '-20.5%', '65.3K'], ['--', '10 weeks', '--', '63.6K'], ['지난주 #79', '10 weeks', '1.5%', '63.4K'], ['지난주 #88', '5 weeks', '11%', '63.4K'], ['--', '1 week', '--', '61.9K'], ['지난주 #69', '3 weeks', '-12.3%', '61.4K'], ['지난주 #75', '12 weeks', '-5.2%', '61K'], ['지난주 #70', '5 weeks', '-11.8%', '60.5K'], ['지난주 #96', '2 weeks', '8.9%', '59.2K'], ['--', '2 weeks', '--', '59K'], ['--', '32 weeks', '--', '58.4K'], ['--', '1 week', '--', '57.4K'], ['--', '26 weeks', '--', '57.4K'], ['지난주 #72', '15 weeks', '-15.9%', '57.3K'], ['지난주 #97', '2 weeks', '5.4%', '56.8K'], ['지난주 #90', '14 weeks', '1.5%', '56.5K'], ['지난주 #93', '8 weeks', '1.2%', '55.8K'] ...

# %% [markdown]
# # 추출한 목록 하나의 리스트로 통합
# ## 100위까지 추출

# %%
youtube_music_chart = []

for i in range(0,len(title)):
    roww = []
    roww.append(str(i+1)+"위")
    roww.append(titles[i])
    roww.append(channel[i])
    roww.append(views_res[i][0])
    roww.append(views_res[i][1])
    roww.append(views_res[i][2])
    roww.append(views_res[i][3])
    youtube_music_chart.append(roww)			#2차원 list로 만들어줌
    
youtube_music_chart[0]
# Out:
# ['1위',
#  "(여자)아이들((G)I-DLE) - 'Oh my god' Official Music Video",
#  '(G)I-DLE (여자)아이들 (Official YouTube Channel)',
#  '--',
#  '1 week',
#  '--',
#  '1.79M']

# %% [markdown]
# # csv 형태로 저장하기
#
# ## 저장된 csv를 바로 실행하면 한글이 깨져있는 것을 확인할 수 있다. 이를 해결하기 위한 절차는 아래와 같다.
#
# ### 저장된 csv 파일을 메모장으로 실행
# ### 다른 이름 저장 ->  인코딩을 ANSI로 지정 (파일형식:csv)
# ### 엑셀로 실행
# #### * csvfile=open() 내부에 저장 위치 지정

# %%
import csv

# %%
csvfile = open("C:/Users/user/Desktop/Goat/python/Desaip/chart.csv","w",-1, "utf-8",newline='')
csvwriter = csv.writer(csvfile)
for row in youtube_music_chart:
    csvwriter.writerow(row)
csvfile.close()
