# %%
import re
from bs4 import BeautifulSoup

import pandas as pd
import requests

# %%
# id 이름 추출

fhand = open("C:\Users\User\Documents\google\git\id_html.html", mode='r', encoding='utf-8')
id_html = fhand.readlines()
fhand.close()
p = re.compile('gallery_view.&#39;(.+?)\&\#39\;\)\;">(.+?)\<\/a\>')
id_all = p.findall(str(id_html))
print(id_all)
# Out:
#   File "<ipython-input-2-0d0972faeca6>", line 1
#     fhand = open("C:\Users\User\Documents\google\git\id_html.html", mode='r', encoding='utf-8')
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# 추출한 id

id_all = [('ohmygirl', '오마이걸'), ('akb48', 'AKB48'), ('iu_new', '아이유'), ('apink', '에이핑크'), ('lovelyz', '러블리즈'), ('twice_new', 'TWICE'), ('top12', '아이즈원'), ('blackpink', '블랙핑크'), ('mamamoo', '마마무'), ('gf', '걸그룹 여자친구'), ('taeyeon_new1', '태연'), ('kdani', '강다니엘'), ('redvelvet', '레드벨벳'), ('nuest', '뉴이스트'), ('wendy', '웬디'), ('japan_entertainment', '일본 연예'), ('bts', '방탄소년단'), ('dahyeon', '다현'), ('infinite', '인피니트'), ('mcthemax', '엠씨 더 맥스'), ('shinee_new', '샤이니'), ('yunha', '윤하'), ('entertainment', '국내연예-남자,여자'), ('seulgi', '슬기'), ('joy', '조이'), ('winkgall', '박지훈'), ('parkbogum', '박보검'), ('jisoo', '서지수'), ('girllaboum', '라붐'), ('nayeone', '나연'), ('irene', '아이린'), ('shinhwa', '신화'), ('6kies', '젝스키스'), ('lovelyzkei', '케이'), ('parkhyoshin', '박효신'), ('monstax', '몬스타 엑스'), ('jjy', '정준영'), ('chungha', '김청하'), ('day6', 'DAY6'), ('ericnam', '에릭남'), ('guckkasten', '국카스텐'), ('zico', '지코'), ('seeya', '씨야'), ('junsu', '김준수'), ('jongshin', '윤종신'), ('pjb', '박재범'), ('joo', '주'), ('mkyunghoon', '민경훈'), ('ej', '정은지'), ('pyc', '박유천'), ('chaekyoung', '윤채경'), ('ksy', '강승윤'), ('straykids', '스트레이 키즈'), ('hyunbin', '현빈'), ('kimsejeong', '김세정'), ('jeonsomi', '전소미'), ('dreamcatcher', '드림캐쳐'), ('jsh', '정승환'), ('kimsohye', '김소혜'), ('jdh', '정동하'), ('sanarang', '사나'), ('buzz', '버즈'), ('youjung', '최유정'), ('cosmicgirl', '우주소녀'), ('winner', '위너'), ('wondergirls_new', '원더걸스'), ('minho', '이민호'), ('joojihun', '주지훈'), ('ysj', '육성재'), ('doitamazing7', '다이아'), ('revelyeri', '예리'), ('vanillalucy', '바닐라루시'), ('ydh', 'YB'), ('exid', 'EXID'), ('nell', '넬'), ('ioi', 'I.O.I'), ('highlight', '하이라이트'), ('boa', '보아'), ('browneyedgirls', '브라운 아이드 걸스'), ('suzy', '수지'), ('eunjiwon', '은지원'), ('jungchaeyeon', '정채연'), ('haein', '정해인'), ('kyw', '김연
ounwoo', '조연우'), ('joojinmo', '주진모'), ('joinsung', '조인성'), ('jitae', '유지태'), ('byh', '변요한'), ('jji', '장재인'), ('bumsu', '이범수'), ('johan', '김조한'), ('jkw', '조관우'), ('kangsora', '강소라'), ('kgr', '김구라'), ('kdw', '강동원'), ('kangjh', '강지환'), ('jungmin', '황정민'), ('jungeum', '황정음'), ('jungouk', '곽정욱'), ('jyj', 'JYJ'), ('ky', '권율'), ('bernardpark', '버나드박'), ('ljw', '이진욱'), ('maybee', '메이비'), ('battle', '배틀'), ('limjueun', '임주은'), ('leeminjung', '이민정'), ('leephilip', '이필립'), ('leekyungkyu', '이경규'), ('leejungjae', '이정재'), ('leejonghyeuk', '이종혁'), ('leeseojin', '이서진'), ('leeseunghyo', '이승효'), ('leesuntae', '이선태'), ('leesk', '이선균'), ('leehyolee', '이효리'), ('leedahae', '이다해'), ('kyongjun', '김용준'), ('lhk', '이현지'), ('lhj', '이현진')]

# %%
# 총 id수와 세부 id 내역

len(id_all)

id_all[215:300]
# Out:
# [('nct', 'NCT'),
#  ('moon', '문근영'),
#  ('phj', '박해진'),
#  ('kimhyunjoo', '김현주'),
#  ('huhgak', '허각'),
#  ('0u', '공유'),
#  ('jinho', '김진호'),
#  ('hyukoh', '혁오'),
#  ('sungrok', '신성록'),
#  ('9muses', '나인뮤지스'),
#  ('suae', '수애'),
#  ('kimbumsoo', '김범수'),
#  ('kwill', '케이윌'),
#  ('yowon', '이요원'),
#  ('jaebum', '임재범'),
#  ('sunnyhill', '써니힐'),
#  ('jihyunwoo', '지현우'),
#  ('epikhigh', '에픽하이'),
#  ('ilwoo', '정일우'),
#  ('taehee', '김태희'),
#  ('deokhwan', '류덕환'),
#  ('jaurim', '자우림'),
#  ('inna', '유인나'),
#  ('shimeunkyung', '심은경'),
#  ('yeadam', '방예담'),
#  ('shj', '서하준'),
#  ('pledis', '프리스틴'),
#  ('bap', 'B.A.P'),
#  ('hakyun', '신하균'),
#  ('leejuck', '이적'),
#  ('kanghodong', '강호동'),
#  ('hyoyeonn', '효연'),
#  ('kwonyuri', '유리'),
#  ('phs', '박하선'),
#  ('hyungdon', '정형돈'),
#  ('ryuhyeyoung', '류혜영'),
#  ('sunmi', '선미'),
#  ('kimajoong', '김아중'),
#  ('amber0918', '엠버'),
#  ('daesung', '대성'),
#  ('noel', '노을'),
#  ('starempire', '제국의 아이들'),
#  ('spica', '스피카'),
#  ('jisung', '지성'),
# ...

# %%
# 크롤링

for id in id_all[0:len(id_all)] : #숫자 조정 필요
    tf = 1
    
    soup = []
    dc = []
    date = []
    view = []
    recmd = []
    numb = []
    singer = []
    
    print(id[1])
    
    while tf:
        base_url = "https://gall.dcinside.com/board/lists"
        params = {'id': str(id[0]),'page':tf}
        headers = {'User-Agent' :'*' }
        
        resp = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(resp.content, 'html.parser')
        contents = soup.find('tbody').find_all('tr',{'class':'ub-content us-post'})
        
        
        for i in contents:
            
            # 날짜 추출 
            date_tag = i.find('td', class_='gall_date')
            
            if date_tag :
                date_dict = date_tag.attrs
                
                if len(date_tag.attrs) is 2:
                    date.append(date_dict['title'])
                
                else:
                    date.append(date_tag.text)
                    pass
                
            # 조회 수 추출
                views_tag = i.find('td', class_='gall_count')
                view.append(views_tag.text)
                
            # 추천 수 추출
                recommend_tag = i.find('td', class_='gall_recommend')
                recmd.append(recommend_tag.text)
                
            # 게시물 number 추출
                numb_tag = i.find('td', class_='gall_num')
                numb.append(numb_tag.text)
                
            # 가수명
                singer.append(id[1])
                
        tf = tf+1
        if (date[-1] < str('2018-04-01 00:00:01')) or (int(numb[-1]) < 50) : tf = False
        
        
    data_frame = pd.DataFrame(dc)
    data_frame['date'] = date
    data_frame['views'] = view
    data_frame['recommend'] = recmd
    data_frame['number'] = numb
    data_frame['singer'] = singer
    
    data_frame.to_csv('C:/Users/User/Documents/google/R/desaip/' + id[1] + '.csv')
# Out:
# NCT
# 문근영
# 박해진
# 김현주
# 허각
# 공유
# 김진호
# 혁오
# 신성록
# 나인뮤지스
# 수애
# 김범수
# 케이윌
# 이요원
# 임재범
# 써니힐
# 지현우
# 에픽하이
# 정일우
# 김태희
# 류덕환
# 자우림
# 유인나
# 심은경
# 방예담
# 서하준
# 프리스틴

# %%
# 크롤링 문제 발생시 나머지 크롤링 해주는 코드

resp.url
print(id)

while tf:
    base_url = "https://gall.dcinside.com/board/lists"
    params = {'id': str(id[0]),'page':tf}
    headers = {'User-Agent' :'*' }
    
    resp = requests.get(base_url, params=params, headers=headers)
    
    soup = BeautifulSoup(resp.content, 'html.parser')
    
    contents = soup.find('tbody').find_all('tr',{'class':'ub-content us-post'})
    
    for i in contents:
        
        # 날짜 추출 
        date_tag = i.find('td', class_='gall_date')
        
        if date_tag :
            date_dict = date_tag.attrs
            
            if len(date_tag.attrs) is 2:
                date.append(date_dict['title'])
            
            else:
                date.append(date_tag.text)
                pass
            
        # 조회 수 추출
            views_tag = i.find('td', class_='gall_count')
            view.append(views_tag.text)
            
        # 추천 수 추출
            recommend_tag = i.find('td', class_='gall_recommend')
            recmd.append(recommend_tag.text)
            
        # 게시물 number 추출
            numb_tag = i.find('td', class_='gall_num')
            numb.append(numb_tag.text)
            
        # 가수명
            singer.append(id[1])
            
    tf = tf+1
    if (date[-1] < str('2018-04-01 00:00:01')) or (int(numb[-1]) < 50) : tf = False
    
    print(tf)
    
data_frame = pd.DataFrame(dc)
data_frame['date'] = date
data_frame['views'] = view
data_frame['recommend'] = recmd
data_frame['number'] = numb
data_frame['singer'] = singer

data_frame.to_csv('C:/Users/User/Documents/google/R/desaip/' + id[1] + '.csv')
# Out:
# ('yooyeonjung', '유연정')
# 600
# 601
# 602
# 603
# 604
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 617
# 618
# 619
# 620
# 621
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# 629
# 630
# 631
# 632
# 633
# 634
# 635
# 636
# 637
# 638
# 639
# 640
# 641
# 642
# 643
# 644
# 645
# 646
# 647
# 648
# 649
# 650
# 651
# 652
# 653
# 654
# 655
# 656
# 657
# 658
# 659
# 660
# 661
# 662
# 663
# 664
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# 672
# 673
# 674
# 675
# 676
# 677
# 678
# 679
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 690
# 691
# 692
# 693
# 694
# 695
# 696
# 697
# 698
# 699
# 700
# 701
# 702
# 703
# 704
# 705
# 706
# 707
# 708
# 709
# 710
# 711
# 712
# 713
# 714
# 715
# 716
# 717
# 718
# 719
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 727
# 728
# 729
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 737
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 747
# 748
# 749
# 750
# 751
# 752
# 753
# 754
# 755
# 756
# 757
# 758
# 759
# 760
# 761
# ...
