# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import urllib
from urllib import request
import re
import json

# %%
import datetime

# %%
data = pd.read_csv("C:/Users/dhxog/Documents/카카오톡 받은 파일/youtube_merge_final.csv")
singer = data["artist"]
singername = list()
for i in np.arange(len(singer)):
    singername.append(singer[i])
temp = set(singername)
temp = list(temp)

# %%
del temp[0]

# %%
temp
# Out:
# ['세훈&찬열',
#  '장덕철',
#  'Imagine Dragons',
#  '임한별',
#  '오마이걸',
#  'Coogie',
#  '이창섭',
#  '송하예',
#  '플라이 투 더 스카이',
#  'EXID',
#  'New Hope Club, Danna Paola',
#  '김길중',
#  '정세운',
#  'IZ*ONE',
#  '염따',
#  '에일리',
#  '우디',
#  '김필, 천단비, 윤종신',
#  '김민규',
#  '임현식',
#  '박우진, 이대휘',
#  '이수영',
#  '가호',
#  'Billie Eilish, Justin Bieber',
#  'Queen',
#  '그리즐리, 청하',
#  '에이프릴 세컨드',
#  '방탄소년단, Charli XCX',
#  '최진호',
#  '어쿠스틱 콜라보',
#  'Adam Levine',
#  '강현준',
#  '옹성우',
#  '정준일',
#  '에피톤 프로젝트',
#  'Dua Lipa',
#  '송민호',
#  '신승훈, 에일리',
#  '인피니트',
#  '뉴이스트',
#  '김동률',
#  'FTISLAND',
#  '포맨',
#  '김하온',
#  '양다일',
#  'ASH ISLAND, 릴러말즈',
#  '세정',
#  '동해',
#  'Ruel',
#  '매드클라운, 스텔라장',
#  '빈첸',
#  '김범수',
#  '허각',
#  '김호중',
#  '윤딴딴',
#  '애즈 원',
#  'GroovyRoom',
#  '기리보이, Kid Milli, NO:EL, 스윙스',
#  '갓츄',
#  '약속',
#  '박재범,사이먼 도미닉',
#  '소유',
#  '산들',
#  '사이먼 도미닉',
#  '휘성',
#  'CHEEZE',
#  '방탄소년단',
#  '전상근',
#  'BLACKPINK',
#  '노을',
#  '세븐틴',
#  'NCT DREAM',
#  'EK',
#  'Lukas Graham',
#  '조정석',
#  'CHANGMO, Hash Swan, ASH ISLAND, 김효은, Leellamarz & The QuiettDingo X Ambition Musik',
#  'Camila Cabello',
#  'Sia',
#  '하진',
#  '오반',
#  '케이윌, 소유, 보이프렌드, 몬스타엑스, 우주소녀, 유승우, 브라더수, 마인드유, 듀에토, 정세운STARSHIP PLANET 2018',
#  '한동근',
#  '홍진영',
#  'Maroon 5',
#  '이수현',
#  'Billie Eilish',
#  '가비엔제이',
#  '박다혜',
#  '볼빨간사춘기, WH3N',
#  '소유, Sik-K',
#  '숀',
#  '볼빨간사춘기',
#  '진민호',
#  '김동준',
#  'P.O',
#  'Post Malone',
#  '이수',
#  '검정치마',
#  'KCM',
#  'DPR LIVE',
#  '찬열',
#  '블랙넛',
#  'Etham',
#  '박경',
#  '자이언티',
#  '임재현, 문성욱',
#  'DAY6',
#  '정동원',
#  '영탁',
#  '몬스타엑스',
#  'Will Smith',
#  '수퍼비',
#  'VICTON',
#  '용준형',
#  'Naomi Scott',
#  '크레파스',
#  'Charlie Puth',
#  '피아노맨',
#  '김필',
#  '김재환',
#  '길구봉구',
#  '비와이',
#  '은지원',
#  'Carla Bruni',
#  '이병재',
#  '박효신',
#  '저스디스',
#  'SUPERBEE',
#  '나플라',
#  '첸',
#  '케이윌',
#  '폴킴, 청하',
#  '윤건',
#  '강민수',
#  '강다니엘',
#  '권순일',
#  '거미',
#  '적재',
#  'X1',
#  'GOT7',
#  '웬디',
#  '박지훈',
#  '아스트로',
#  '에픽하이',
#  '지아',
#  '이영지',
#  '서은광, 이창섭, 임현식, 육성재',
#  '송가인',
#  '임창정',
#  '헤이즈',
#  'OLNL',
#  'Marshmello, Anne-Marie',
#  '비투비',
#  '염따, 딥플로우, 팔로알토',
#  '태민',
#  'Mena Massoud',
#  '국.슈',
#  'Kristen Bell, Idina Menzel, Josh Gad, Jonathan Groff, Cast of Frozen 2Frozen 2',
#  'Josh Gad',
#  '로코베리, 도영',
#  '펀치',
#  'EXO-CBX',
#  'Idina Menzel, AURORA',
#  '샤이니',
#  '박진영',
#  '휘인',
#  '이문세',
#  '성시경, 박효신, 서인국, 빅스',
#  '정기고',
#  '윤미래',
#  '정인',
#  '보이비, 개코, 최자, 지구인, GRAY',
#  'pH-1, Kid Milli, 루피',
#  '이석훈',
#  'Mena Massoud, Naomi Scott',
#  'MC몽',
#  'Mike Perry',
#  'Adele',
#  'Evan Rachel Wood',
#  '윤민수, 치타, 백호',
#  '박보람',
#  'Coogie, SUPERBEE, D.Ark',
#  'Stevie Wonder & Andra Day',
#  'MINO',
#  'Summer Wish',
#  'FANXY CHILD',
#  '윤종신, 민서',
#  '성시경, 박효신, 이석훈, 서인국, 빅스',
#  '이소라',
#  '승리',
#  '로코베리',
#  '박재범',
#  '다이나믹 듀오, 첸',
#  '기리보이, NO:EL, 블랙넛',
#  '데.비',
#  '새벽 한 시',
#  '(여자)아이들',
#  '에이치코드',
#  '민현',
#  '멜로망스',
#  '황치열',
#  'Ed Sheeran, Justin Bieber',
#  '이승철',
#  '양다일, 빈센트블루',
#  '스윙스',
#  '악동뮤지션',
#  'Idina Menzel, Evan Rachel Wood',
#  '백아연',
#  '히키',
#  'Anne-Marie',
#  'ASH ISLAND',
#  '아이유',
#  '이우',
#  'The Chainsmokers',
#  'Tones And I',
#  '나얼',
#  'SG워너비, 브라운 아이드 걸스',
#  'EXO',
#  '오왠',
#  'Ariana Grande',
#  'Justin Bieber',
#  'Lauv, Troye Sivan',
#  '닐로',
#  '에이트',
#  '이찬원',
#  '이용신',
#  'The Weeknd',
#  '강민경',
#  'Jonas Brothers',
#  'Shawn Mendes, Camila Cabello',
#  'TWICE',
#  '공기남',
#  'Christopher',
#  'Alan Walker',
#  '스탠딩 에그',
#  '오반, 빈첸',
#  'Straight No Chaser',
#  'Mariah Carey',
#  '민서',
#  '곽진언',
#  '키드밀리',
#  '이민혁',
#  'Dua Lipa, BLACKPINK',
#  '오반, VAN.C',
#  'Conan Gray',
#  '스텔라장',
#  '마마무',
#  '정준일, 권진아',
#  'Michael Buble',
#  'NO:EL',
#  'Dan + Shay, Justin Bieber',
#  '신화',
#  'ITZY',
#  'John Legend',
#  '에이프릴',
#  '창모, Hash Swan, ASH ISLAND, 김효은',
#  'Jvcki Wai, Young B, Osshun Gum, 한요한',
#  'iKON',
#  'Jonathan Groff',
#  '버스커 버스커',
#  '백예린',
#  'Selena Gomez',
#  '배연서',
#  'Wanna One',
#  '모모랜드',
#  '이해리',
#  'NCT 127',
#  '화사',
#  '존박',
#  'Lauv, Anne-Marie',
#  '볼빨간사춘기, 바닐라 어쿠스틱, 스웨덴세탁소, 스무살, 레터플로우, 김지수, WH3N',
#  'Taylor Swift',
#  '디오',
#  '하성운',
#  '엔플라잉',
#  'AB6IX',
#  '청하',
#  '다이나믹 듀오',
#  '비, 소유',
#  'Ed Sheeran',
#  '러블리즈',
#  '권영훈',
#  '키',
#  '임재현',
#  '뉴이스트 W',
#  '보아',
#  '규현',
#  'HYNN',
#  '유산슬, 송가인',
#  '슬기',
#  '정승환',
#  'The Chainsmokers, Coldplay',
#  '루피',
#  '잔나비',
#  'nafla, OLNL',
#  '폴킴, 헤이즈',
#  'Dua Lipa, 화사',
#  'Lauv',
#  '염따, 창모',
#  '서동현',
#  'Zedd, Alessia Cara',
#  'Ariana Grande, Social House',
#  '로꼬, 화사',
#  '육성재',
#  '남우현',
#  '임영웅',
#  '개코',
#  '솔라, 케이시',
#  '에이핑크',
#  '5 Seconds of Summer',
#  'Panic! At The Disco',
#  'PRODUCE X 101',
#  '모트',
#  '펭수, 타이거JK, 비지',
#  '마미손',
#  'Kristen Bell',
#  'Alessia Cara',
#  'Sondia',
#  '전소미',
#  '앤씨아, HYNN',
#  '찬열, 세훈',
#  'Fitz & The Tantrums',
#  'CHEEZE, pH-1',
#  '여은',
#  '윤비',
#  '먼데이키즈',
#  'JINU',
#  '헨리',
#  '장혜진, 윤민수',
#  '방탄소년단, Juice WRLD',
#  '수퍼비, UNEDUCATED KID',
#  '박재범, 우원재',
#  '폴킴',
#  '권진아',
#  '수란',
#  '투모로우바이투게더',
#  '박봄',
#  '샘김',
#  '박효신, 박성연',
#  '송민재',
#  '핑클',
#  '김효은, 차붐, EK',
#  'god',
#  '기억 조작단',
#  '하은',
#  '이진혁',
#  '정은지',
#  '슈퍼주니어',
#  '박보검',
#  '제니',
#  '프리스타일',
#  '맴맴',
#  '10cm',
#  'nafla, pH-1, Kid Milli, OLNL',
#  'Khalid, Disclosure',
#  'SIXC',
#  'Liam Payne',
#  '백지영',
#  '황인욱',
#  'UMI',
#  '성시경',
#  '젝스키스',
#  '벤',
#  '한요한',
#  '빅뱅',
#  '오담률',
#  '하현우',
#  '유산슬',
#  'V',
#  'HIGH4, 아이유',
#  'GRAY',
#  '엠씨더맥스',
#  '송이한',
#  'Post Malone & Swae Lee',
#  '정효빈',
#  '양다일, 웬디',
#  '장범준',
#  'Jeremy Zucker',
#  '로이킴',
#  '박재정',
#  '브라운 아이드 걸스',
#  '예리',
#  '로꼬',
#  'Sam Smith',
#  '소녀시대-Oh!GG',
#  'Marshmello & Anne-Marie',
#  'Arizona Zervas',
#  'Shawn Mendes',
#  '지코',
#  '씨야',
#  'Kiana Lede',
#  '솔라',
#  '우주소녀',
#  '수호',
#  'Alan Walker, Sabrina Carpenter, Farruko',
#  '양요섭',
#  'pH-1',
#  '코드 쿤스트',
#  '하동균',
#  'Halsey, SUGA',
#  '카더가든',
#  '보라미유',
#  '선미',
#  '로꼬, 우원재',
#  '브라운 아이드 소울',
#  '양승호',
#  '박혜나, Aurora',
#  'Martin Garrix',
#  '청하, 마미손',
#  '비투비-블루',
#  '김나영, 양다일',
#  '먼데이 키즈',
#  '빈지노',
#  '크러쉬',
#  'Harry Styles',
#  '박봄, 산다라박',
#  '태용',
#  '이하이',
#  '시우민',
#  '김재환, 스텔라장',
#  '효린',
#  '넬',
#  '양희은, 성시경',
#  '짱유',
#  'AOA',
#  '조이',
#  '이동은',
#  '케이시',
#  '반하나',
#  '윤하',
#  '방탄소년단, Zara Larsson',
#  '펀치넬로',
#  '다비치',
#  '로꼬, GRAY',
#  '펜타곤',
#  '성시경, 아이유',
#  'Steve Aoki',
#  'V.O.S',
#  'Troye Sivan',
#  '레드벨벳',
#  '태연',
#  '에일리, 정승환',
#  '이예준',
#  '거미, 에일리',
#  '로시',
#  'CL',
#  '하이라이트',
#  '백현',
#  'WINNER',
#  '그루비룸',
#  '개리',
#  '김나영',
#  'Sik-K',
#  '혁오',
#  '신예영',
#  '기리보이',
#  '김현성',
#  '윤종신',
#  '김효은',
#  '바이브',
#  '정동원, 장민호',
#  '마크툽',
#  'MC몽, 김재환',
#  '윤민수, 송가인, 치타',
#  '영비',
#  '하은요셉',
#  'SF9',
#  '창모',
#  '린',
#  'Woodie Gochild, 최엘비',
#  '임영웅, 김수찬',
#  '어반 자카파',
#  'DEAN',
#  'Pink Sweat$',
#  'Idina Menzel',
#  '최강창민',
#  '문별',
#  'Doja Cat',
#  '현아',
#  '우원재',
#  '여자친구',
#  '김민석',
#  '코드쿤스트',
#  '문문',
#  '윤지성',
#  '에릭남',
#  '러브포션',
#  '박원',
#  '유노윤호']

# %%
singer = list()
for i in np.arange(len(temp)):
    singer = singer + temp[i].split(",")
m = re.compile(".+(?=\()")
singername = list()
for i in np.arange(len(singer)):
    t = m.search(singer[i])
    if t == None:
        singername.append(singer[i])
    else:
        singername.append(t.group())
singer = list()
for i in np.arange(len(singername)):
    singer.append(singername[i].strip())
temp = set(singer)
singer = list(temp)
singer.remove("Cast of Frozen 2Frozen 2")
singer.remove("Leellamarz & The QuiettDingo X Ambition Musik")

# %%
client_id = "RLpoOMH7S702D1xpvVfA"
client_secret = "RbICRLuPbD"
url = "https://openapi.naver.com/v1/datalab/search";

# %%
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")

# %%
keywords = singer

# %%
len(singer)
# Out:
# 476

# %%
navertrend = pd.DataFrame()
indexlist = list()
for i in np.arange(0, len(keywords)):

    bodytext = {"startDate":"2018-04-22",
            "endDate":"2020-04-25",
            "timeUnit":"week",
            "keywordGroups":[{"groupName":"{}".format(keywords[i]),
                              "keywords": ["{}".format(keywords[i])]}]
                             }

    body = json.dumps(bodytext,ensure_ascii = False )
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        scraped = response_body.decode('utf-8')
    else:
            print("Error Code:" + rescode)
    result = json.loads(scraped)
    data = result["results"][0]["data"]
    time = list(i["period"] for i in data)
    value = pd.DataFrame(i["ratio"] for i in data)
    
    # 실행이 되는 index만 뽑아준다
    if str(value) != 'Empty DataFrame\nColumns: []\nIndex: []':
        indexlist = indexlist + [keywords[i]]
    
    
    navertrend = navertrend.append(np.transpose(value))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#    1421             self.sock = self._context.wrap_socket(self.sock,
# -> 1422                                                   server_hostname=server_hostname)
#    1423
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-23-326291169d89> in <module>
#      11
#      12     body = json.dumps(bodytext,ensure_ascii = False )
# ---> 13     response = urllib.request.urlopen(request, data=body.encode("utf-8"))
#      14     rescode = response.getcode()
#      15     if(rescode==200):
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#    1323         except:
#
# URLError: <urlopen error [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다>

# %% [markdown]
# ### 많이 크롤링하면 중간에 접속이 끊겨서 반복해 크롤링한다

# %%
for i in np.arange(singer.index(indexlist[-1]), len(keywords)):

    bodytext = {"startDate":"2018-04-22",
            "endDate":"2020-04-25",
            "timeUnit":"week",
            "keywordGroups":[{"groupName":"{}".format(keywords[i]),
                              "keywords": ["{}".format(keywords[i])]}]
                             }

    body = json.dumps(bodytext,ensure_ascii = False )
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        scraped = response_body.decode('utf-8')
    else:
            print("Error Code:" + rescode)
    result = json.loads(scraped)
    data = result["results"][0]["data"]
    time = list(i["period"] for i in data)
    value = pd.DataFrame(i["ratio"] for i in data)
    
    # 실행이 되는 index만 뽑아준다
    if str(value) != 'Empty DataFrame\nColumns: []\nIndex: []':
        indexlist = indexlist + [keywords[i]]
    
    
    navertrend = navertrend.append(np.transpose(value))

# %%
for i in np.arange(singer.index(indexlist[-1]), len(keywords)):

    bodytext = {"startDate":"2018-04-22",
            "endDate":"2020-04-25",
            "timeUnit":"week",
            "keywordGroups":[{"groupName":"{}".format(keywords[i]),
                              "keywords": ["{}".format(keywords[i])]}]
                             }

    body = json.dumps(bodytext,ensure_ascii = False )
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        scraped = response_body.decode('utf-8')
    else:
            print("Error Code:" + rescode)
    result = json.loads(scraped)
    data = result["results"][0]["data"]
    time = list(i["period"] for i in data)
    value = pd.DataFrame(i["ratio"] for i in data)
    
    # 실행이 되는 index만 뽑아준다
    if str(value) != 'Empty DataFrame\nColumns: []\nIndex: []':
        indexlist = indexlist + [keywords[i]]
    
    
    navertrend = navertrend.append(np.transpose(value))

# %%
navertrend
# Out:
#          0         1         2         3         4         5         6    \
# 0    0.16276  22.36328  42.28515  49.54427  81.96614  31.38020  22.65625
# 0   27.96135  14.64632  15.74277  14.09246  10.91142   9.41392   7.42637
# 0   11.54078  11.63584  11.90805  13.74870  14.59989  16.69979  17.78430
# 0    2.09633   2.02481   1.76109   1.96734   2.10335   2.03439   2.13655
# 0   22.18770  17.16875  16.54585  15.72123  13.34714  13.84590  12.46805
# ..       ...       ...       ...       ...       ...       ...       ...
# 0    2.37963   2.11313   2.12772   2.89096   3.48525   2.03629   1.83898
# 0   11.45822   4.16843   2.92707  19.41712   3.74077   6.52777   3.56385
# 0    9.10041   6.43305   6.85146   8.89121   7.94979   7.68828   6.58995
# 0   29.17438  27.39900  30.56343  29.65452  48.76169  34.87348  24.80180
# 0    2.95617   2.16064   4.23987   2.53750   2.08579   2.38164   2.54740
#
#          7         8         9    ...       96        97        98        99   \
# 0   22.55859  13.83463  10.18880  ...       NaN       NaN       NaN       NaN
# 0    6.74973   5.67634   4.90587  ...   2.06261   2.04170   1.86208   1.80793
# 0   16.33252  15.33442  15.14431  ...   5.94538   5.53923   6.33857   6.36017
# 0    1.78472   1.30517   1.18130  ...   3.19525   2.79617   2.17295   2.21318
# 0   11.89392  11.33721  11.09591  ...  11.52690  11.61177  43.91781  22.88533
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 0    2.80662   2.26833   1.75186  ...   0.78214   0.63735   1.17439   0.71600
# 0    1.87032   3.09127   1.70638  ...   0.83848   0.90408   0.94317   0.92714
# 0    8.36820  10.51255   7.32217  ...   6.74686   5.91004   5.91004   7.26987
# 0   22.93932  22.33859  38.20764  ...  16.04770  11.98999  13.98870  13.84354
# 0    3.01405   2.53477   2.58972  ...   1.40167   1.34107   1.24582   1.43813
#
#          100       101       102       103       104        105
# 0        NaN       NaN       NaN       NaN       NaN        NaN
# 0    1.65888   2.87221   1.77094   1.84546   8.24509   52.50575
# 0    6.43363   6.51140   6.27376   7.02557   6.81386    6.37746
# 0    2.19019  10.89287   4.66326   3.49665   2.87854    2.92004
# 0   17.56617  17.22733  18.02408  18.50194  29.92656  100.00000
# ..       ...       ...       ...       ...       ...        ...
# 0    0.60470   0.67709   0.62846   0.53717   0.56218    0.50299
# 0    1.10220   1.24798   1.06417   1.06934   1.17204    1.50932
# 0    6.69456   5.91004   5.12552   5.64853   5.23012    4.70711
# 0   14.24998  11.38033  11.98999  11.52549  12.70461   12.09942
# 0    1.36975  11.16977   2.66547   2.26963   6.82858    1.75186
#
# [475 rows x 106 columns]

# %%
navertrend.columns = time
navertrend.index = indexlist

# %%
navertrend = navertrend.transpose()

# %%
navertrend.to_csv("navertrend크롤링.csv", mode = 'w', encoding = 'utf-8-sig')
